# %% [markdown]
# This Notebook is a start to the AI Capstone Project Course.

# %%
import pandas as pd #import pandas library
import numpy as np #import numpy library

print('Hello Capstonr Project Course!')
